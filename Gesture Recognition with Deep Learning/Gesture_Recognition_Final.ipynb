# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started. Once you have completed the code you can download the notebook for making a submission.

# %%
import numpy as np
import os
from imageio import imread
from skimage.transform import resize
import datetime
import os

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from tensorflow import keras
import tensorflow as tf
tf.random.set_seed(30)

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
def plot(history):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))
    axes[0].plot(history.history['loss'])   
    axes[0].plot(history.history['val_loss'])
    axes[0].legend(['loss','val_loss'])

    axes[1].plot(history.history['categorical_accuracy'])   
    axes[1].plot(history.history['val_categorical_accuracy'])
    axes[1].legend(['categorical_accuracy','val_accuracy'])

# %% [markdown]
# **data path: /home/datasets/Project_data**

# %%
train_doc = np.random.permutation(open('/home/datasets/Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('/home/datasets/Project_data/val.csv').readlines())
# Our Hyperparameters
batch_size = 32 #experiment with the batch size
image_height=120
image_width=120
channels=3
num_classes=5
total_frames=30
frame_samples=16
num_epochs = 62

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
def generator(source_path, folder_list, batch_size):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx = np.round(np.linspace(0,total_frames-1,frame_samples)).astype(int)#create a list of image numbers you want to use for a particular video
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(t)//batch_size# calculate the number of batches

        for batch in range(num_batches): # we iterate over the number of batches

            remaining_seq=0 #To track for remainning sequence

            batch_data = np.zeros((batch_size,len(img_idx),image_height,image_width,3)) # len(img_idx) is the number of images you use for each video, (image_height,image_width) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    if image.shape[0] != image.shape[1]:
                        image=image[0:120,10:150]
                    else:
                        image=image[30:330,20:340]

                    image_resized=resize(image,(image_height,image_width,3))
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255 #normalise and feed in the image

                    
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        
        # write the code for the remaining data points which are left after full batches
        remaining_seq=len(t)%batch_size #To track for remainning sequence
        
        if (remaining_seq != 0):
            seq_len = remaining_seq #To track for remainning sequence

            batch_data = np.zeros((seq_len,len(img_idx),image_height,image_width,3)) # len(img_idx) is the number of images you use for each video, (image_height,image_width) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((seq_len,5)) # batch_labels is the one hot representation of the output
            for folder in range(seq_len): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    if image.shape[0] != image.shape[1]:
                        image=image[0:120,10:150]
                    else:
                        image=image[30:340,20:340]
                    image_resized=resize(image,(image_height,image_width,3))
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255 #normalise and feed in the image

                    
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = '/home/datasets/Project_data/train'
val_path = '/home/datasets/Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 62

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU, Dropout, Flatten, BatchNormalization, Activation, Conv3D, MaxPooling3D
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import optimizers

#write your model here
model = Sequential()
model.add(Conv3D(16, (3,3,3), padding='same',input_shape=(frame_samples,image_height,image_width,channels)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
#model.add(Dropout(0.4))


model.add(Conv3D(32, (3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
#model.add(Dropout(0.4))


model.add(Conv3D(64, (3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(Dropout(0.4))


#model.add(Conv3D(128, (3,3,3), padding='same'))
#model.add(Activation('relu'))
#model.add(BatchNormalization())
#model.add(MaxPooling3D(pool_size=(2, 2, 2)))

model.add(Flatten())
model.add(Dense(256,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

#model.add(Dense(128,activation='relu'))
#model.add(BatchNormalization())
#model.add(Dropout(0.5))

model.add(Dense(num_classes,activation='softmax'))

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = optimizers.Adam(lr=0.00009)#write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_6 (Conv3D)            (None, 16, 120, 120, 16)  1312
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 16, 120, 120, 16)  64
# _________________________________________________________________
# activation_6 (Activation)    (None, 16, 120, 120, 16)  0
# _________________________________________________________________
# max_pooling3d_6 (MaxPooling3 (None, 8, 60, 60, 16)     0
# _________________________________________________________________
# conv3d_7 (Conv3D)            (None, 8, 60, 60, 32)     13856
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 8, 60, 60, 32)     128
# _________________________________________________________________
# activation_7 (Activation)    (None, 8, 60, 60, 32)     0
# _________________________________________________________________
# max_pooling3d_7 (MaxPooling3 (None, 4, 30, 30, 32)     0
# _________________________________________________________________
# conv3d_8 (Conv3D)            (None, 4, 30, 30, 64)     55360
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 4, 30, 30, 64)     256
# _________________________________________________________________
# activation_8 (Activation)    (None, 4, 30, 30, 64)     0
# _________________________________________________________________
# max_pooling3d_8 (MaxPooling3 (None, 2, 15, 15, 64)     0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2, 15, 15, 64)     0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 28800)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               7373056
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 1285
# =================================================================
# Total params: 7,446,341
# Trainable params: 7,445,605
# Non-trainable params: 736
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto',period = 1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.01, patience=5, cooldown=4, verbose=1,mode='auto',epsilon=0.0001)# write the REducelronplateau code here
callbacks_list = [checkpoint, LR]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit` method to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  /home/datasets/Project_data/train ; batch size = 32
# Epoch 1/62
# 21/21 [==============================] - ETA: 0s - loss: 1.8154 - categorical_accuracy: 0.4012Source path =  /home/datasets/Project_data/val ; batch size = 32
#
# Epoch 00001: saving model to model_2021-06-2504_13_36.214091/model-00001-1.81537-0.40121-1.77226-0.25000.h5
# 21/21 [==============================] - 72s 3s/step - loss: 1.8154 - categorical_accuracy: 0.4012 - val_loss: 1.7723 - val_categorical_accuracy: 0.2500
# Epoch 2/62
# 21/21 [==============================] - ETA: 0s - loss: 0.9409 - categorical_accuracy: 0.6290
# Epoch 00002: saving model to model_2021-06-2504_13_36.214091/model-00002-0.94092-0.62896-2.56079-0.30000.h5
# 21/21 [==============================] - 72s 3s/step - loss: 0.9409 - categorical_accuracy: 0.6290 - val_loss: 2.5608 - val_categorical_accuracy: 0.3000
# Epoch 3/62
# 21/21 [==============================] - ETA: 0s - loss: 0.6677 - categorical_accuracy: 0.7617
# Epoch 00003: saving model to model_2021-06-2504_13_36.214091/model-00003-0.66766-0.76169-3.40839-0.20000.h5
# 21/21 [==============================] - 71s 3s/step - loss: 0.6677 - categorical_accuracy: 0.7617 - val_loss: 3.4084 - val_categorical_accuracy: 0.2000
# Epoch 4/62
# 21/21 [==============================] - ETA: 0s - loss: 0.4673 - categorical_accuracy: 0.8386
# Epoch 00004: saving model to model_2021-06-2504_13_36.214091/model-00004-0.46725-0.83861-3.67109-0.20000.h5
# 21/21 [==============================] - 72s 3s/step - loss: 0.4673 - categorical_accuracy: 0.8386 - val_loss: 3.6711 - val_categorical_accuracy: 0.2000
# Epoch 5/62
# 21/21 [==============================] - ETA: 0s - loss: 0.3999 - categorical_accuracy: 0.8597
# Epoch 00005: saving model to model_2021-06-2504_13_36.214091/model-00005-0.39990-0.85973-4.18931-0.21000.h5
# 21/21 [==============================] - 76s 4s/step - loss: 0.3999 - categorical_accuracy: 0.8597 - val_loss: 4.1893 - val_categorical_accuracy: 0.2100
# Epoch 6/62
# 21/21 [==============================] - ETA: 0s - loss: 0.3027 - categorical_accuracy: 0.8959
# Epoch 00006: saving model to model_2021-06-2504_13_36.214091/model-00006-0.30267-0.89593-4.22587-0.22000.h5
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 9.000000136438757e-07.
# 21/21 [==============================] - 72s 3s/step - loss: 0.3027 - categorical_accuracy: 0.8959 - val_loss: 4.2259 - val_categorical_accuracy: 0.2200
# Epoch 7/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2569 - categorical_accuracy: 0.9170
# Epoch 00007: saving model to model_2021-06-2504_13_36.214091/model-00007-0.25688-0.91704-4.65392-0.19000.h5
# 21/21 [==============================] - 73s 3s/step - loss: 0.2569 - categorical_accuracy: 0.9170 - val_loss: 4.6539 - val_categorical_accuracy: 0.1900
# Epoch 8/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2646 - categorical_accuracy: 0.8824
# Epoch 00008: saving model to model_2021-06-2504_13_36.214091/model-00008-0.26456-0.88235-4.88830-0.20000.h5
# 21/21 [==============================] - 70s 3s/step - loss: 0.2646 - categorical_accuracy: 0.8824 - val_loss: 4.8883 - val_categorical_accuracy: 0.2000
# Epoch 9/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2824 - categorical_accuracy: 0.9080
# Epoch 00009: saving model to model_2021-06-2504_13_36.214091/model-00009-0.28243-0.90799-4.69520-0.20000.h5
# 21/21 [==============================] - 72s 3s/step - loss: 0.2824 - categorical_accuracy: 0.9080 - val_loss: 4.6952 - val_categorical_accuracy: 0.2000
# Epoch 10/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2487 - categorical_accuracy: 0.9140
# Epoch 00010: saving model to model_2021-06-2504_13_36.214091/model-00010-0.24866-0.91403-4.71359-0.23000.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.2487 - categorical_accuracy: 0.9140 - val_loss: 4.7136 - val_categorical_accuracy: 0.2300
# Epoch 11/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2717 - categorical_accuracy: 0.9170
# Epoch 00011: saving model to model_2021-06-2504_13_36.214091/model-00011-0.27167-0.91704-4.77922-0.17000.h5
# 21/21 [==============================] - 73s 3s/step - loss: 0.2717 - categorical_accuracy: 0.9170 - val_loss: 4.7792 - val_categorical_accuracy: 0.1700
# Epoch 12/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2466 - categorical_accuracy: 0.9170
# Epoch 00012: saving model to model_2021-06-2504_13_36.214091/model-00012-0.24665-0.91704-4.44107-0.21000.h5
# 21/21 [==============================] - 70s 3s/step - loss: 0.2466 - categorical_accuracy: 0.9170 - val_loss: 4.4411 - val_categorical_accuracy: 0.2100
# Epoch 13/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2524 - categorical_accuracy: 0.9155
# Epoch 00013: saving model to model_2021-06-2504_13_36.214091/model-00013-0.25238-0.91554-4.19670-0.22000.h5
# 21/21 [==============================] - 71s 3s/step - loss: 0.2524 - categorical_accuracy: 0.9155 - val_loss: 4.1967 - val_categorical_accuracy: 0.2200
# Epoch 14/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2824 - categorical_accuracy: 0.8929
# Epoch 00014: saving model to model_2021-06-2504_13_36.214091/model-00014-0.28240-0.89291-4.18340-0.20000.h5
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 9.000000318337697e-09.
# 21/21 [==============================] - 74s 4s/step - loss: 0.2824 - categorical_accuracy: 0.8929 - val_loss: 4.1834 - val_categorical_accuracy: 0.2000
# Epoch 15/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2565 - categorical_accuracy: 0.9095
# Epoch 00015: saving model to model_2021-06-2504_13_36.214091/model-00015-0.25652-0.90950-3.68835-0.17000.h5
# 21/21 [==============================] - 75s 4s/step - loss: 0.2565 - categorical_accuracy: 0.9095 - val_loss: 3.6884 - val_categorical_accuracy: 0.1700
# Epoch 16/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2824 - categorical_accuracy: 0.8959
# Epoch 00016: saving model to model_2021-06-2504_13_36.214091/model-00016-0.28236-0.89593-3.25624-0.24000.h5
# 21/21 [==============================] - 70s 3s/step - loss: 0.2824 - categorical_accuracy: 0.8959 - val_loss: 3.2562 - val_categorical_accuracy: 0.2400
# Epoch 17/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2630 - categorical_accuracy: 0.9095
# Epoch 00017: saving model to model_2021-06-2504_13_36.214091/model-00017-0.26304-0.90950-2.85082-0.27000.h5
# 21/21 [==============================] - 73s 3s/step - loss: 0.2630 - categorical_accuracy: 0.9095 - val_loss: 2.8508 - val_categorical_accuracy: 0.2700
# Epoch 18/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2204 - categorical_accuracy: 0.9261
# Epoch 00018: saving model to model_2021-06-2504_13_36.214091/model-00018-0.22038-0.92609-2.49878-0.36000.h5
# 21/21 [==============================] - 73s 3s/step - loss: 0.2204 - categorical_accuracy: 0.9261 - val_loss: 2.4988 - val_categorical_accuracy: 0.3600
# Epoch 19/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2593 - categorical_accuracy: 0.9035
# Epoch 00019: saving model to model_2021-06-2504_13_36.214091/model-00019-0.25928-0.90347-1.90112-0.38000.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.2593 - categorical_accuracy: 0.9035 - val_loss: 1.9011 - val_categorical_accuracy: 0.3800
# Epoch 20/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2332 - categorical_accuracy: 0.9231
# Epoch 00020: saving model to model_2021-06-2504_13_36.214091/model-00020-0.23315-0.92308-1.72016-0.40000.h5
# 21/21 [==============================] - 71s 3s/step - loss: 0.2332 - categorical_accuracy: 0.9231 - val_loss: 1.7202 - val_categorical_accuracy: 0.4000
# Epoch 21/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2349 - categorical_accuracy: 0.9186
# Epoch 00021: saving model to model_2021-06-2504_13_36.214091/model-00021-0.23487-0.91855-1.34703-0.56000.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.2349 - categorical_accuracy: 0.9186 - val_loss: 1.3470 - val_categorical_accuracy: 0.5600
# Epoch 22/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2630 - categorical_accuracy: 0.9020
# Epoch 00022: saving model to model_2021-06-2504_13_36.214091/model-00022-0.26302-0.90196-1.11089-0.59000.h5
# 21/21 [==============================] - 73s 3s/step - loss: 0.2630 - categorical_accuracy: 0.9020 - val_loss: 1.1109 - val_categorical_accuracy: 0.5900
# Epoch 23/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2610 - categorical_accuracy: 0.9110
# Epoch 00023: saving model to model_2021-06-2504_13_36.214091/model-00023-0.26102-0.91101-0.96356-0.65000.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.2610 - categorical_accuracy: 0.9110 - val_loss: 0.9636 - val_categorical_accuracy: 0.6500
# Epoch 24/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2464 - categorical_accuracy: 0.9201
# Epoch 00024: saving model to model_2021-06-2504_13_36.214091/model-00024-0.24638-0.92006-0.82777-0.69000.h5
# 21/21 [==============================] - 71s 3s/step - loss: 0.2464 - categorical_accuracy: 0.9201 - val_loss: 0.8278 - val_categorical_accuracy: 0.6900
# Epoch 25/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2606 - categorical_accuracy: 0.9065
# Epoch 00025: saving model to model_2021-06-2504_13_36.214091/model-00025-0.26057-0.90649-0.70422-0.72000.h5
# 21/21 [==============================] - 73s 3s/step - loss: 0.2606 - categorical_accuracy: 0.9065 - val_loss: 0.7042 - val_categorical_accuracy: 0.7200
# Epoch 26/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2385 - categorical_accuracy: 0.9276
# Epoch 00026: saving model to model_2021-06-2504_13_36.214091/model-00026-0.23851-0.92760-0.71567-0.68000.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.2385 - categorical_accuracy: 0.9276 - val_loss: 0.7157 - val_categorical_accuracy: 0.6800
# Epoch 27/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2942 - categorical_accuracy: 0.8808
# Epoch 00027: saving model to model_2021-06-2504_13_36.214091/model-00027-0.29417-0.88084-0.60511-0.76000.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.2942 - categorical_accuracy: 0.8808 - val_loss: 0.6051 - val_categorical_accuracy: 0.7600
# Epoch 28/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2732 - categorical_accuracy: 0.8989
# Epoch 00028: saving model to model_2021-06-2504_13_36.214091/model-00028-0.27324-0.89894-0.56580-0.80000.h5
# 21/21 [==============================] - 70s 3s/step - loss: 0.2732 - categorical_accuracy: 0.8989 - val_loss: 0.5658 - val_categorical_accuracy: 0.8000
# Epoch 29/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2641 - categorical_accuracy: 0.9035
# Epoch 00029: saving model to model_2021-06-2504_13_36.214091/model-00029-0.26410-0.90347-0.50449-0.83000.h5
# 21/21 [==============================] - 73s 3s/step - loss: 0.2641 - categorical_accuracy: 0.9035 - val_loss: 0.5045 - val_categorical_accuracy: 0.8300
# Epoch 30/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2345 - categorical_accuracy: 0.9125
# Epoch 00030: saving model to model_2021-06-2504_13_36.214091/model-00030-0.23445-0.91252-0.41500-0.88000.h5
# 21/21 [==============================] - 73s 3s/step - loss: 0.2345 - categorical_accuracy: 0.9125 - val_loss: 0.4150 - val_categorical_accuracy: 0.8800
# Epoch 31/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2298 - categorical_accuracy: 0.9186
# Epoch 00031: saving model to model_2021-06-2504_13_36.214091/model-00031-0.22983-0.91855-0.53660-0.79000.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.2298 - categorical_accuracy: 0.9186 - val_loss: 0.5366 - val_categorical_accuracy: 0.7900
# Epoch 32/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2670 - categorical_accuracy: 0.9020
# Epoch 00032: saving model to model_2021-06-2504_13_36.214091/model-00032-0.26700-0.90196-0.48149-0.83000.h5
# 21/21 [==============================] - 70s 3s/step - loss: 0.2670 - categorical_accuracy: 0.9020 - val_loss: 0.4815 - val_categorical_accuracy: 0.8300
# Epoch 33/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2722 - categorical_accuracy: 0.8989
# Epoch 00033: saving model to model_2021-06-2504_13_36.214091/model-00033-0.27220-0.89894-0.45628-0.83000.h5
# 21/21 [==============================] - 73s 3s/step - loss: 0.2722 - categorical_accuracy: 0.8989 - val_loss: 0.4563 - val_categorical_accuracy: 0.8300
# Epoch 34/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2671 - categorical_accuracy: 0.9110
# Epoch 00034: saving model to model_2021-06-2504_13_36.214091/model-00034-0.26707-0.91101-0.49943-0.78000.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.2671 - categorical_accuracy: 0.9110 - val_loss: 0.4994 - val_categorical_accuracy: 0.7800
# Epoch 35/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2819 - categorical_accuracy: 0.9005
# Epoch 00035: saving model to model_2021-06-2504_13_36.214091/model-00035-0.28190-0.90045-0.32699-0.90000.h5
# 21/21 [==============================] - 73s 3s/step - loss: 0.2819 - categorical_accuracy: 0.9005 - val_loss: 0.3270 - val_categorical_accuracy: 0.9000
# Epoch 36/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2775 - categorical_accuracy: 0.9050
# Epoch 00036: saving model to model_2021-06-2504_13_36.214091/model-00036-0.27747-0.90498-0.48126-0.82000.h5
# 21/21 [==============================] - 71s 3s/step - loss: 0.2775 - categorical_accuracy: 0.9050 - val_loss: 0.4813 - val_categorical_accuracy: 0.8200
# Epoch 37/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2505 - categorical_accuracy: 0.9140
# Epoch 00037: saving model to model_2021-06-2504_13_36.214091/model-00037-0.25045-0.91403-0.46840-0.83000.h5
# 21/21 [==============================] - 73s 3s/step - loss: 0.2505 - categorical_accuracy: 0.9140 - val_loss: 0.4684 - val_categorical_accuracy: 0.8300
# Epoch 38/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2509 - categorical_accuracy: 0.9216
# Epoch 00038: saving model to model_2021-06-2504_13_36.214091/model-00038-0.25093-0.92157-0.51640-0.83000.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.2509 - categorical_accuracy: 0.9216 - val_loss: 0.5164 - val_categorical_accuracy: 0.8300
# Epoch 39/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2642 - categorical_accuracy: 0.9201
# Epoch 00039: saving model to model_2021-06-2504_13_36.214091/model-00039-0.26425-0.92006-0.51184-0.82000.h5
# 21/21 [==============================] - 73s 3s/step - loss: 0.2642 - categorical_accuracy: 0.9201 - val_loss: 0.5118 - val_categorical_accuracy: 0.8200
# Epoch 40/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2316 - categorical_accuracy: 0.9170
# Epoch 00040: saving model to model_2021-06-2504_13_36.214091/model-00040-0.23161-0.91704-0.44431-0.87000.h5
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 9.000000744663339e-11.
# 21/21 [==============================] - 71s 3s/step - loss: 0.2316 - categorical_accuracy: 0.9170 - val_loss: 0.4443 - val_categorical_accuracy: 0.8700
# Epoch 41/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2528 - categorical_accuracy: 0.9140
# Epoch 00041: saving model to model_2021-06-2504_13_36.214091/model-00041-0.25280-0.91403-0.46380-0.86000.h5
# 21/21 [==============================] - 73s 3s/step - loss: 0.2528 - categorical_accuracy: 0.9140 - val_loss: 0.4638 - val_categorical_accuracy: 0.8600
# Epoch 42/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2214 - categorical_accuracy: 0.9397
# Epoch 00042: saving model to model_2021-06-2504_13_36.214091/model-00042-0.22141-0.93967-0.52164-0.83000.h5
# 21/21 [==============================] - 73s 3s/step - loss: 0.2214 - categorical_accuracy: 0.9397 - val_loss: 0.5216 - val_categorical_accuracy: 0.8300
# Epoch 43/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2255 - categorical_accuracy: 0.9291
# Epoch 00043: saving model to model_2021-06-2504_13_36.214091/model-00043-0.22549-0.92911-0.45174-0.87000.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.2255 - categorical_accuracy: 0.9291 - val_loss: 0.4517 - val_categorical_accuracy: 0.8700
# Epoch 44/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2359 - categorical_accuracy: 0.9201
# Epoch 00044: saving model to model_2021-06-2504_13_36.214091/model-00044-0.23592-0.92006-0.46915-0.86000.h5
# 21/21 [==============================] - 72s 3s/step - loss: 0.2359 - categorical_accuracy: 0.9201 - val_loss: 0.4692 - val_categorical_accuracy: 0.8600
# Epoch 45/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2368 - categorical_accuracy: 0.9125
# Epoch 00045: saving model to model_2021-06-2504_13_36.214091/model-00045-0.23683-0.91252-0.48054-0.84000.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.2368 - categorical_accuracy: 0.9125 - val_loss: 0.4805 - val_categorical_accuracy: 0.8400
# Epoch 46/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2790 - categorical_accuracy: 0.8914
# Epoch 00046: saving model to model_2021-06-2504_13_36.214091/model-00046-0.27905-0.89140-0.48982-0.87000.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.2790 - categorical_accuracy: 0.8914 - val_loss: 0.4898 - val_categorical_accuracy: 0.8700
# Epoch 47/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2508 - categorical_accuracy: 0.9261
# Epoch 00047: saving model to model_2021-06-2504_13_36.214091/model-00047-0.25078-0.92609-0.45915-0.84000.h5
# 21/21 [==============================] - 73s 3s/step - loss: 0.2508 - categorical_accuracy: 0.9261 - val_loss: 0.4592 - val_categorical_accuracy: 0.8400
# Epoch 48/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2380 - categorical_accuracy: 0.9035
# Epoch 00048: saving model to model_2021-06-2504_13_36.214091/model-00048-0.23797-0.90347-0.45712-0.86000.h5
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 9.00000074466334e-13.
# 21/21 [==============================] - 71s 3s/step - loss: 0.2380 - categorical_accuracy: 0.9035 - val_loss: 0.4571 - val_categorical_accuracy: 0.8600
# Epoch 49/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2780 - categorical_accuracy: 0.9065
# Epoch 00049: saving model to model_2021-06-2504_13_36.214091/model-00049-0.27801-0.90649-0.44908-0.86000.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.2780 - categorical_accuracy: 0.9065 - val_loss: 0.4491 - val_categorical_accuracy: 0.8600
# Epoch 50/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2715 - categorical_accuracy: 0.9050
# Epoch 00050: saving model to model_2021-06-2504_13_36.214091/model-00050-0.27145-0.90498-0.43824-0.84000.h5
# 21/21 [==============================] - 75s 4s/step - loss: 0.2715 - categorical_accuracy: 0.9050 - val_loss: 0.4382 - val_categorical_accuracy: 0.8400
# Epoch 51/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2352 - categorical_accuracy: 0.9125
# Epoch 00051: saving model to model_2021-06-2504_13_36.214091/model-00051-0.23524-0.91252-0.37739-0.87000.h5
# 21/21 [==============================] - 75s 4s/step - loss: 0.2352 - categorical_accuracy: 0.9125 - val_loss: 0.3774 - val_categorical_accuracy: 0.8700
# Epoch 52/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2717 - categorical_accuracy: 0.9050
# Epoch 00052: saving model to model_2021-06-2504_13_36.214091/model-00052-0.27168-0.90498-0.46109-0.86000.h5
# 21/21 [==============================] - 71s 3s/step - loss: 0.2717 - categorical_accuracy: 0.9050 - val_loss: 0.4611 - val_categorical_accuracy: 0.8600
# Epoch 53/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2652 - categorical_accuracy: 0.9005
# Epoch 00053: saving model to model_2021-06-2504_13_36.214091/model-00053-0.26519-0.90045-0.45308-0.87000.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.2652 - categorical_accuracy: 0.9005 - val_loss: 0.4531 - val_categorical_accuracy: 0.8700
# Epoch 54/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2715 - categorical_accuracy: 0.8974
# Epoch 00054: saving model to model_2021-06-2504_13_36.214091/model-00054-0.27151-0.89744-0.43340-0.88000.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.2715 - categorical_accuracy: 0.8974 - val_loss: 0.4334 - val_categorical_accuracy: 0.8800
# Epoch 55/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2498 - categorical_accuracy: 0.9201
# Epoch 00055: saving model to model_2021-06-2504_13_36.214091/model-00055-0.24979-0.92006-0.51626-0.83000.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.2498 - categorical_accuracy: 0.9201 - val_loss: 0.5163 - val_categorical_accuracy: 0.8300
# Epoch 56/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2507 - categorical_accuracy: 0.9170
# Epoch 00056: saving model to model_2021-06-2504_13_36.214091/model-00056-0.25073-0.91704-0.46046-0.86000.h5
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 9.000000722979295e-15.
# 21/21 [==============================] - 70s 3s/step - loss: 0.2507 - categorical_accuracy: 0.9170 - val_loss: 0.4605 - val_categorical_accuracy: 0.8600
# Epoch 57/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2429 - categorical_accuracy: 0.9170
# Epoch 00057: saving model to model_2021-06-2504_13_36.214091/model-00057-0.24292-0.91704-0.44683-0.86000.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.2429 - categorical_accuracy: 0.9170 - val_loss: 0.4468 - val_categorical_accuracy: 0.8600
# Epoch 58/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2744 - categorical_accuracy: 0.9020
# Epoch 00058: saving model to model_2021-06-2504_13_36.214091/model-00058-0.27441-0.90196-0.46855-0.83000.h5
# 21/21 [==============================] - 74s 4s/step - loss: 0.2744 - categorical_accuracy: 0.9020 - val_loss: 0.4685 - val_categorical_accuracy: 0.8300
# Epoch 59/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2531 - categorical_accuracy: 0.8989
# Epoch 00059: saving model to model_2021-06-2504_13_36.214091/model-00059-0.25307-0.89894-0.51781-0.84000.h5
# 21/21 [==============================] - 79s 4s/step - loss: 0.2531 - categorical_accuracy: 0.8989 - val_loss: 0.5178 - val_categorical_accuracy: 0.8400
# Epoch 60/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2766 - categorical_accuracy: 0.8944
# Epoch 00060: saving model to model_2021-06-2504_13_36.214091/model-00060-0.27658-0.89442-0.46504-0.86000.h5
# 21/21 [==============================] - 71s 3s/step - loss: 0.2766 - categorical_accuracy: 0.8944 - val_loss: 0.4650 - val_categorical_accuracy: 0.8600
# Epoch 61/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2292 - categorical_accuracy: 0.9155
# Epoch 00061: saving model to model_2021-06-2504_13_36.214091/model-00061-0.22918-0.91554-0.47261-0.86000.h5
# 21/21 [==============================] - 76s 4s/step - loss: 0.2292 - categorical_accuracy: 0.9155 - val_loss: 0.4726 - val_categorical_accuracy: 0.8600
# Epoch 62/62
# 21/21 [==============================] - ETA: 0s - loss: 0.2613 - categorical_accuracy: 0.9050
# Epoch 00062: saving model to model_2021-06-2504_13_36.214091/model-00062-0.26132-0.90498-0.35986-0.87000.h5
# 21/21 [==============================] - 75s 4s/step - loss: 0.2613 - categorical_accuracy: 0.9050 - val_loss: 0.3599 - val_categorical_accuracy: 0.8700

# %%
import matplotlib.pyplot as plt
plot(history)
